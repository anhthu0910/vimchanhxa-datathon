# %% [markdown]
# # Phần 1: Trả lời câu hỏi trắc nghiệm

# %%
import sys
from pathlib import Path

sys.path.append(str(Path('..').resolve()))
from src.connection import get_connection

# %%
con = get_connection()
df = con.execute("SELECT * FROM products LIMIT 5").df()
display(df)
# Out:
#    product_id      product_name    category   segment size   color      price  \
# 0         536  SaigonFlex UC-01  Streetwear  Everyday    S   green  11059.650
# 1         537  SaigonFlex UC-02  Streetwear  Everyday    M  silver   9523.076
# 2         538  SaigonFlex UC-03  Streetwear  Everyday    L    pink  15951.633
# 3         539  SaigonFlex UC-04  Streetwear  Everyday   XL  yellow  15753.717
# 4         540  SaigonFlex UC-05  Streetwear  Everyday    S     red  15766.335
#
#         cogs
# 0   9704.843
# 1   5393.870
# 2  11371.919
# 3   8573.173
# 4  14063.570

# %%
df['price'].dtype
# Out:
# dtype('float64')
